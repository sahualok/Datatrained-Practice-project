# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('abalone case study.csv')
df
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 0      M   0.455     0.365   0.095        0.5140          0.2245
# 1      M   0.350     0.265   0.090        0.2255          0.0995
# 2      F   0.530     0.420   0.135        0.6770          0.2565
# 3      M   0.440     0.365   0.125        0.5160          0.2155
# 4      I   0.330     0.255   0.080        0.2050          0.0895
# ...   ..     ...       ...     ...           ...             ...
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 0             0.1010        0.1500     15
# 1             0.0485        0.0700      7
# 2             0.1415        0.2100      9
# ...

# %%
df.sample(5)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 1811   M   0.650     0.525   0.190        1.6125          0.7770
# 3645   I   0.475     0.335   0.100        0.4425          0.1895
# 301    F   0.540     0.435   0.175        0.8920          0.3220
# 3043   M   0.575     0.445   0.140        0.7370          0.3250
# 2548   I   0.275     0.195   0.070        0.0875          0.0345
#
#       Viscera weight  Shell weight  Rings
# 1811          0.3685        0.3965     11
# 3645          0.0860        0.1350      9
# 301           0.1740        0.3350     13
# 3043          0.1405        0.2370     10
# 2548          0.0220        0.0255      4

# %%
df.tail()
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 4172   F   0.565     0.450   0.165        0.8870          0.3700
# 4173   M   0.590     0.440   0.135        0.9660          0.4390
# 4174   M   0.600     0.475   0.205        1.1760          0.5255
# 4175   F   0.625     0.485   0.150        1.0945          0.5310
# 4176   M   0.710     0.555   0.195        1.9485          0.9455
#
#       Viscera weight  Shell weight  Rings
# 4172          0.2390        0.2490     11
# 4173          0.2145        0.2605     10
# 4174          0.2875        0.3080      9
# 4175          0.2610        0.2960     10
# 4176          0.3765        0.4950     12

# %%
df.dtypes
# Out:
# Sex                object
# Length            float64
# Diameter          float64
# Height            float64
# Whole weight      float64
# Shucked weight    float64
# Viscera weight    float64
# Shell weight      float64
# Rings               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Whole weight', 'Shucked weight',
#        'Viscera weight', 'Shell weight', 'Rings'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %% [markdown]
# interpretation:
#
#     1)there are total 9 rows and 4177 columns
#     2)with 7 are float 1 interger and 1 is objective
#     3)no null value present in the dataset

# %% [markdown]
# # checking for null values

# %%
sns.heatmap(df.isnull())

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %% [markdown]
# interpretation: no null value present in the dataset

# %%
df['Sex'].value_counts()
# Out:
# M    1528
# I    1342
# F    1307
# Name: Sex, dtype: int64

# %%
sns.countplot(df['Sex'])

# %% [markdown]
# interpretation: male has slightly more abalone than other two

# %%
#encoding the csex column for furthur analysis
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['Sex']=le.fit_transform(df['Sex'])
df['Sex'].sample(5)
# Out:
# 2287    0
# 2375    2
# 3367    1
# 3373    2
# 319     1
# Name: Sex, dtype: int32

# %%
df.sample(5)
# Out:
#       Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 3152    0   0.470     0.375   0.105        0.5130          0.2320
# 2881    1   0.495     0.375   0.120        0.6140          0.2855
# 122     0   0.515     0.425   0.140        0.7660          0.3040
# 1603    1   0.540     0.430   0.140        0.8195          0.3935
# 754     2   0.650     0.515   0.175        1.4805          0.5295
#
#       Viscera weight  Shell weight  Rings
# 3152          0.1420        0.1300     11
# 2881          0.1365        0.1610      8
# 122           0.1725        0.2550     14
# 1603          0.1725        0.2295      9
# 754           0.2720        0.5250     20

# %%
#summary statistics
df.describe()
# Out:
#                Sex       Length     Diameter       Height  Whole weight  \
# count  4177.000000  4177.000000  4177.000000  4177.000000   4177.000000
# mean      1.052909     0.523992     0.407881     0.139516      0.828742
# std       0.822240     0.120093     0.099240     0.041827      0.490389
# min       0.000000     0.075000     0.055000     0.000000      0.002000
# 25%       0.000000     0.450000     0.350000     0.115000      0.441500
# 50%       1.000000     0.545000     0.425000     0.140000      0.799500
# 75%       2.000000     0.615000     0.480000     0.165000      1.153000
# max       2.000000     0.815000     0.650000     1.130000      2.825500
#
#        Shucked weight  Viscera weight  Shell weight        Rings
# count     4177.000000     4177.000000   4177.000000  4177.000000
# mean         0.359367        0.180594      0.238831     9.933684
# std          0.221963        0.109614      0.139203     3.224169
# ...

# %% [markdown]
# interpretation:
#
#     1)all attributes mean value is less than 1
#     2)variation from mean in the dataset is less than 1
#     3)the mean and median value is approx. same
#     4)difference in the third quartile and max value is minimum so outliers may not present
#     4)

# %%
#correlation
dfcorr=df.corr()
dfcorr
# Out:
#                      Sex    Length  Diameter    Height  Whole weight  \
# Sex             1.000000 -0.036066 -0.038874 -0.042077     -0.021391
# Length         -0.036066  1.000000  0.986812  0.827554      0.925261
# Diameter       -0.038874  0.986812  1.000000  0.833684      0.925452
# Height         -0.042077  0.827554  0.833684  1.000000      0.819221
# Whole weight   -0.021391  0.925261  0.925452  0.819221      1.000000
# Shucked weight -0.001373  0.897914  0.893162  0.774972      0.969405
# Viscera weight -0.032067  0.903018  0.899724  0.798319      0.966375
# Shell weight   -0.034854  0.897706  0.905330  0.817338      0.955355
# Rings          -0.034627  0.556720  0.574660  0.557467      0.540390
#
#                 Shucked weight  Viscera weight  Shell weight     Rings
# Sex                  -0.001373       -0.032067     -0.034854 -0.034627
# Length                0.897914        0.903018      0.897706  0.556720
# ...

# %%
plt.figure(figsize=(8,4))
sns.heatmap(dfcorr,annot=True)

# %% [markdown]
# interpretation:
#
#     1)the sex variable is negatively coreelated to the all other variable
#     2)variable lenghth is high positively related to all other variables
#     3)all other variable is positively related to all other variables

# %%
#eda 
#univariate data analysis
df['Rings'].value_counts()
# Out:
# 9     689
# 10    634
# 8     568
# 11    487
# 7     391
# 12    267
# 6     259
# 13    203
# 14    126
# 5     115
# 15    103
# 16     67
# 17     58
# 4      57
# 18     42
# 19     32
# 20     26
# 3      15
# 21     14
# 23      9
# 22      6
# 24      2
# 27      2
# 1       1
# 25      1
# 2       1
# 26      1
# 29      1
# Name: Rings, dtype: int64

# %%
#sex has negative correlation so we delete this column
df.drop(columns=['Sex'],axis=1,inplace=True)

# %%
sns.countplot(df['Rings'])

# %%
sns.violinplot(df['Rings'])

# %% [markdown]
# interpretation:
#
# 1)having abalone 8,9,10,11 rings are most in the dataset
# 2)minimum age and max age are having 1 value in the dataset.

# %%
#biivariate analysis
sns.scatterplot(df['Diameter'],df['Length'])
plt.show()
sns.scatterplot(df['Whole weight'],df['Shucked weight'])
plt.show()

# %% [markdown]
# interpretation:
#
#     1)as we can see that lenght and weight are linearly positively scattered
#     2)shucked and whole weight are positively related with cone like structure

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(df['Rings'],df['Length'])
plt.show()
plt.figure(figsize=(10,6))
sns.swarmplot(df['Rings'],df['Diameter'])
plt.show()

# %% [markdown]
# interpretation:as length and Diameter increaes upto 0.6 mm  and 5.5mm resp.
# then rings increases then it doent depend on length ane Diameter

# %%
#multivariate analysis
sns.pairplot(df)

# %% [markdown]
# interpretation:
#
#     1)all variables are positively related i.e. x increses then y also increses
#     2)all variables are not linearly related

# %%
#checking for outliers
collist=df.columns.values
plt.figure(figsize=(20,50))
for i in range(1,len(collist)):
    plt.subplot(10,14,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout

# %% [markdown]
# interpretation:
#
#     outliers are present n the dataset

# %%
#remove outliers
from scipy.stats import zscore
z=np.abs(zscore(df))
df_new=df[(z<3).all(axis=1)]
print(df.shape,df_new.shape)
# Out:
# (4027, 8) (3967, 8)

# %%
df=df_new

# %%
df.shape
# Out:
# (3967, 8)

# %%
#cheking for skewness
#distribution plot of all variables
plt.figure(figsize=(25,15))
for i in range(1,len(collist)):
    plt.subplot(5,5,i+1)
    sns.distplot(df[collist[i]],color='green')
    plt.tight_layout()

# %%
df.skew()
# Out:
# Length           -0.607088
# Diameter         -0.587306
# Height           -0.235642
# Whole weight      0.305860
# Shucked weight    0.427220
# Viscera weight    0.405311
# Shell weight      0.313289
# Rings             0.617514
# dtype: float64

# %% [markdown]
# interpretation:slightly skewness is present in some variable

# %%
#x Y splitting

# %%
x=df.iloc[:,:-1]
x.head()
# Out:
#    Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight
# 0         0.150
# 1         0.070
# 2         0.210
# 3         0.155
# 4         0.055

# %%
y=df.iloc[:,-1:]
y.head()
# Out:
#    Rings
# 0     15
# 1      7
# 2      9
# 3     10
# 4      7

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=42)
print('xtrain shape--->',x_train.shape)
print('ytrain shape--->',y_train.shape)
print('xtest shape--->',x_test.shape)
print('ytest shape--->',y_test.shape)
# Out:
# xtrain shape---> (3094, 7)
# ytrain shape---> (3094, 1)
# xtest shape---> (873, 7)
# ytest shape---> (873, 1)

# %%
#model building

from sklearn.naive_bayes import MultinomialNB   
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# %%
#regression model
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import r2_score

# %%
lrm=LinearRegression()
lrm.fit(x_train,y_train)
print(lrm.coef_)
print(lrm.intercept_)
score=lrm.score(x_train,y_train)
print('score:',score)
pred=lrm.predict(x_test)
print('errors:')
print('mean squared error:',mean_squared_error(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score:',r2_score(y_test,pred))
print('score:',score*100,'%')
# Out:
# [[ -1.73519883  12.14329175  21.4253822    6.08406619 -16.29757699
#    -6.5339793    8.69212648]]
# [2.64907607]
# score: 0.5180806400512149
# errors:
# mean squared error: 3.773519303993648
# mean absolute error: 1.463322836405281
# root mean squared error: 1.9425548393787104
# r2 score: 0.49561888381022345
# score: 51.80806400512149 %

# %%
#Using Grid Search to check the best parameters for SVm

from sklearn.model_selection import GridSearchCV
svr=SVR()
parameters={'kernel':('linear','poly','rbf','sigmoid'),'C':[1,10]}
clf=GridSearchCV(svc,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# {'C': 10, 'kernel': 'rbf'}

# %%
#Using SVC() from SVM

svr=SVR(kernel='rbf',C=10)
svr.fit(x_train,y_train)
score=svr.score(x_train,y_train)
print('score:',score)
pred=svr.predict(x_test)
print('errors:')
print('mean squared error:',mean_squared_error(y_test,pred))
print('mean absolute error:',mean_absolute_error(y_test,pred))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
print('r2 score:',r2_score(y_test,pred))
print('score:',score*100,'%')
# Out:
# score: 0.5572960042231445
# errors:
# mean squared error: 3.6663034275456954
# mean absolute error: 1.3794252340997066
# root mean squared error: 1.9147593654414372
# r2 score: 0.509949713754263
# score: 55.72960042231445 %

# %%
#Using Grid Search to check the best parameters for decision tree 

from sklearn.model_selection import GridSearchCV
dt=DecisionTreeClassifier()
parameters={'criterion':('gini','entropy')}
clf=GridSearchCV(dt,parameters,scoring='accuracy',cv=5)
clf.fit(x,y)
clf.best_params_
# Out:
# {'criterion': 'gini'}

# %%
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
preddtr=dtr.predict(x_test)
score=svr.score(x_train,y_train)
print('score:',score)
print('errors:')
print('mean squared error:',mean_squared_error(y_test,preddtr))
print('mean absolute error:',mean_absolute_error(y_test,preddtr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,preddtr)))
print('r2 score:',r2_score(y_test,preddtr))
print('score:',score*100,'%')
# Out:
# score: 0.5572960042231445
# errors:
# mean squared error: 6.710194730813288
# mean absolute error: 1.8946162657502863
# root mean squared error: 2.590404356623361
# r2 score: 0.1030930981070024
# score: 55.72960042231445 %

# %%
knr=KNeighborsRegressor()
knr.fit(x_train,y_train)
predknr=knr.predict(x_test)
score=knr.score(x_train,y_train)
print('score:',score)
print('errors:')
print('mean squared error:',mean_squared_error(y_test,predknr))
print('mean absolute error:',mean_absolute_error(y_test,predknr))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,predknr)))
print('r2 score:',r2_score(y_test,predknr))
print('score:',score*100,'%')
# Out:
# score: 0.6644220351092232
# errors:
# mean squared error: 3.9303550973654073
# mean absolute error: 1.4712485681557848
# root mean squared error: 1.982512319599908
# r2 score: 0.4746556910591919
# score: 66.44220351092231 %

# %%
rf=RandomForestRegressor(n_estimators=250,random_state=42)
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
score=rf.score(x_train,y_train)
print('score:',score)
print('errors:')
print('mean squared error:',mean_squared_error(y_test,predrf))
print('mean absolute error:',mean_absolute_error(y_test,predrf))
print('root mean squared error:',np.sqrt(mean_squared_error(y_test,predrf)))
print('r2 score:',r2_score(y_test,predrf))
print('score:',score*100,'%')
# Out:
# score: 0.9359879995265971
# errors:
# mean squared error: 3.6017673676975948
# mean absolute error: 1.416348224513173
# root mean squared error: 1.897832281234987
# r2 score: 0.5185758177379436
# score: 93.5987999526597 %

# %%
#random forest regressor having maximum score and minimum mean squared error so we use this model

# %%
#Saving the model
import joblib

#Save the model as a pickle in a file
joblib.dump(rf,'abalon_case_study.pkl')
# Out:
# ['abalon_case_study.pkl']
